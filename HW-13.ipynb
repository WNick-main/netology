# %% [markdown]
# # Домашнее задание к лекции "Основы веб-скрапинга и работы с API"

# %% [markdown]
# ## Задание 1.
#
# ### Обязательная часть

# %% [markdown]
# Будем парсить страницу со свежеми новостям на [habr.com/ru/all/](https://habr.com/ru/all/).
#
# Вам необходимо собирать только те статьи, в которых встречается хотя бы одно требуемое ключевое слово. Эти слова определяем в начале кода в переменной, например:
#
# `KEYWORDS = ['python', 'парсинг']`
#
#  Поиск вести по всей доступной preview-информации (это информация, доступная непосредственно с текущей страницы).
#
# В итоге должен формироваться датафрейм вида: `<дата> - <заголовок> - <ссылка>`

# %% [markdown]
# ### Дополнительная часть (необязательная)

# %% [markdown]
# Улучшить скрипт так, чтобы он анализировал не только preview-информацию статьи, но и весь текст статьи целиком.
#
# Для этого потребуется получать страницы статей и искать по тексту внутри этой страницы.
#
# Итоговый датафрейм формировать со столбцами: `<дата> - <заголовок> - <ссылка> - <текст_статьи>`

# %%
from bs4 import BeautifulSoup
import requests, time
from fake_useragent import UserAgent
import pandas as pd

class Connect:
  
    def __init__(self):
        self.headers = headers = {'User-Agent': UserAgent().chrome} #.random
        self.hooks = {'response': self.response_info}
        self.session = self.get_session()
        
    def response_info(self,r, *args, **kwargs):
        print(r.status_code, r.url)
        #print(r.text)
        
    def get_session(self):
        return requests.Session()
    
    def get_soup(self,URL):
        res = self.session.get(URL, headers=self.headers,hooks=self.hooks)
        time.sleep(0.2)
        return BeautifulSoup(res.text,'html.parser')

#params
KEYWORDS = ['python', 'парсинг']
source = 'https://habr.com/ru/all/'

# %%
def get_short_news(soup, ses):
    '''
    Возвращаем датафрейм со всеми новостями со страницы
    <дата> - <заголовок> - <ссылка> - <текст_статьи>
    '''
    all_data = pd.DataFrame()
    
    #addr_list = list(map(lambda x: x.find('article').get('id'),ar_list))
    #page_count = max(list(map(lambda x: x.text.strip(),page_list)))
    #page_count
    
    ar_list = soup.find_all('article',class_='tm-articles-list__item')
    for item in ar_list:
        date =  item.find('time').get('title') 
        title =  item.find('h2').find('span').text
        ref = 'https://habr.com' + item.find('a',class_='tm-article-snippet__title-link').get('href')
        #desc = item.select('div[class*="article-formatted-body article-formatted-body_version-"]')[0].text.strip()
        all_text = get_all_text(soup = ses.get_soup(ref))
        
        row = {'date':date, 'header':title, 'ref':ref, 'text':all_text}
        
        all_data = pd.concat([all_data,pd.DataFrame([row])],sort=False)
        #all_data = all_data.reindex(['date','header','ref','text'], axis=1)
    return all_data

# %%
def get_all_text(soup):
    all_text = soup.find('div',xmlns='http://www.w3.org/1999/xhtml').text
    return all_text

# %%
ses = Connect()
soup = ses.get_soup(source)
soup

df_news = get_short_news(soup,ses)
news_filt = df_news[df_news['text'].str.lower().str.split(expand = True).isin(KEYWORDS).any(1)]
news_filt
# Out:
# 200 https://habr.com/ru/all/
# 200 https://habr.com/ru/company/selectel/blog/570016/
# 200 https://habr.com/ru/post/571798/
# 200 https://habr.com/ru/post/571796/
# 200 https://habr.com/ru/company/samsung/blog/571264/
# 200 https://habr.com/ru/post/530488/
# 200 https://habr.com/ru/post/570780/
# 200 https://habr.com/ru/post/571758/
# 200 https://habr.com/ru/post/571784/
# 200 https://habr.com/ru/company/audiomania/blog/571750/
# 200 https://habr.com/ru/post/571782/
# 200 https://habr.com/ru/company/ruvds/blog/570744/
# 200 https://habr.com/ru/company/skillfactory/blog/570586/
# 200 https://habr.com/ru/post/571748/
# 200 https://habr.com/ru/company/productivity_inside/blog/571776/
# 200 https://habr.com/ru/post/571772/
# 200 https://habr.com/ru/post/571770/
# 200 https://habr.com/ru/post/571764/
# 200 https://habr.com/ru/post/571762/
# 200 https://habr.com/ru/post/569552/
# 200 https://habr.com/ru/company/ruvds/blog/569814/
#                 date                                             header  \
# 0  2021-08-08, 16:57  Технический подход к пониманию интерфейсов моз...
#
#                                                  ref  \
# 0  https://habr.com/ru/company/skillfactory/blog/...
#
#                                                 text
# 0  Изображение оценки источника с использованием ...

# %% [markdown]
# ## Задание 2.

# %% [markdown]
# ### Обязательная часть

# %% [markdown]
# Написать скрипт, который будет проверять список e-mail адресов на утечку при помощи сервиса [Avast Hack Ckeck](https://www.avast.com/hackcheck/).
# Список email-ов задаем переменной в начале кода:
# `EMAIL = [xxx@x.ru, yyy@y.com]`
#
# В итоге должен формироваться датафрейм со столбцами: `<дата утечки> - <источник утечки> - <описание утечки>`
#
# **Подсказка**: сервис работает при помощи "скрытого" API. Внимательно изучите post-запросы.

# %%
import json
from bs4 import BeautifulSoup
import requests, time
import pandas as pd

source='https://identityprotection.avast.com/v1/web/query/site-breaches/unauthorized-data'
headers = {
    'Accept': 'application/json, text/plain, */*'
    ,'Accept-Encoding':'gzip, deflate, br'
    ,'Accept-Language': 'ru,en;q=0.9,en-GB;q=0.8,en-US;q=0.7'
    ,'Connection': 'keep-alive'
    ,'Content-Length': '35'
    ,'Content-Type': 'application/json;charset=UTF-8'
    ,'Host': 'identityprotection.avast.com'
    ,'Origin': 'https://www.avast.com'
    ,'Referer': 'https://www.avast.com/'
    ,'sec-ch-ua': 'Chromium;v=92, Not A;Brand;v=99, Microsoft Edge;v=92'
    ,'sec-ch-ua-mobile': '?0'
    ,'Sec-Fetch-Dest': 'empty'
    ,'Sec-Fetch-Mode': 'cors'
    ,'Sec-Fetch-Site': 'same-site'
    ,'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/92.0.4515.107 Safari/537.36 Edg/92.0.902.62'
    ,'Vaar-Header-App-Build-Version': '1.0.0'
    ,'Vaar-Header-App-Product': 'hackcheck-web-avast'
    ,'Vaar-Header-App-Product-Name': 'hackcheck-web-avast'
    ,'Vaar-Version': '0'
}
payload = {
    'emailAddresses': ['test@mail.ru','xxx@x.ru', 'yyy@y.com']
}

session = requests.Session()
res = session.post(source, headers=headers,json=payload)

# %%
df = pd.DataFrame()
site_json=json.loads(res.text)
for item in site_json['breaches']:
    date = site_json['breaches'][item]['publishDate']
    site = site_json['breaches'][item]['site']
    description = site_json['breaches'][item]['description']
    
    row = {'date':date, 'site':site, 'description':description}
    df = pd.concat([df,pd.DataFrame([row])],sort=False)
df
# Out:
#                     date                                        description  \
# 0   2019-03-20T00:00:00Z  In July 2018, Bookmate was allegedly breached....
# 0   2019-02-28T00:00:00Z  In July 2018, 500px's database was allegedly b...
# 0   2019-03-07T00:00:00Z  In July 2018, ShareThis's database was alleged...
# 0   2019-03-07T00:00:00Z  In December 2018, Dubsmash's database was alle...
# 0   2019-02-28T00:00:00Z  In July 2018, 8fit's database was allegedly br...
# 0   2019-03-14T00:00:00Z  In May 2018, Artsy's database was allegedly br...
# 0   2019-03-20T00:00:00Z  In January 2019, Roll20 allegedly breached. Th...
# 0   2019-03-14T00:00:00Z  In June 2018, Streeteasy's database was allege...
# 0   2019-05-23T00:00:00Z  In 2017, social network LiveJournal's database...
# 0   2019-06-13T00:00:00Z  In May 2019, graphic-design site Canva's datab...
# 0   2019-07-25T00:00:00Z  In February 2019, custom merchandise retailer ...
# 0   2019-08-08T00:00:00Z  At an unconfirmed date, Russian server hosting...
# 0   2019-08-08T00:00:00Z  In January 2016, Uzbek entertainment site mnog...
# 0   2019-10-03T00:00:00Z  At an unknown date, printer supply store Lencr...
# 0   2019-10-17T00:00:00Z  In September 2019, the game developer Zynga wa...
# 0   2020-01-03T00:00:00Z  At an unconfirmed date, online Arizona newspap...
# 0   2020-01-30T00:00:00Z  At an unconfirmed date, the online gaming site...
# 0   2020-04-09T00:00:00Z  At an unconfirmed date, the Russian social med...
# 0   2020-05-07T00:00:00Z  At an unconfirmed date, the Russian investment...
# 0   2020-04-30T00:00:00Z  At an unconfirmed date, the UK online toy reta...
# 0   2020-04-23T00:00:00Z  In April 2020, the software marketplace app Ap...
# 0   2020-08-27T00:00:00Z  At an unconfirmed date, the now-defunct Russia...
# 0   2020-05-21T00:00:00Z  In April 2020, the e-commerce platform BitRewa...
# 0   2020-05-28T00:00:00Z  In January 2020, the online poll website Wishb...
# 0   2020-06-18T00:00:00Z  At an unconfirmed date, the social media influ...
# 0   2020-07-16T00:00:00Z  At an unconfirmed date, the Russian university...
# 0   2020-07-23T00:00:00Z  In June 2020, the online writing community Wat...
# 0   2020-08-13T00:00:00Z  At an unconfirmed date, the now-defunct hackin...
# 0   2020-10-22T00:00:00Z  At an unconfirmed date, the Russian online sto...
# 0   2020-08-27T00:00:00Z  In August 2020, the international transfer boo...
# ..                   ...                                                ...
# 0   2020-12-10T00:00:00Z  In November 2020, a collection of over 23,000 ...
# 0   2020-12-10T00:00:00Z  In November 2020, a collection of over 23,000 ...
# 0   2020-12-10T00:00:00Z  In November 2020, a collection of over 23,000 ...
# 0   2020-12-10T00:00:00Z  In November 2020, a collection of over 23,000 ...
# 0   2020-12-10T00:00:00Z  In November 2020, a collection of over 23,000 ...
# 0   2020-12-03T00:00:00Z  In November 2020, a collection of over 23,000 ...
# 0   2020-12-10T00:00:00Z  In November 2020, a collection of over 23,000 ...
# 0   2020-12-10T00:00:00Z  In November 2020, a collection of over 23,000 ...
# 0   2020-12-10T00:00:00Z  In November 2020, a collection of over 23,000 ...
# 0   2020-12-03T00:00:00Z  In November 2020, a collection of over 23,000 ...
# 0   2020-12-03T00:00:00Z  In November 2020, a collection of over 23,000 ...
# 0   2020-12-10T00:00:00Z  In November 2020, a collection of over 23,000 ...
# 0   2020-12-10T00:00:00Z  In November 2020, a collection of over 23,000 ...
# 0   2020-12-10T00:00:00Z  In November 2020, a collection of over 23,000 ...
# 0   2020-12-10T00:00:00Z  In November 2020, a collection of over 23,000 ...
# 0   2021-02-11T00:00:00Z  At an unconfirmed date, the Russian-language m...
# 0   2021-01-21T00:00:00Z  At an unconfirmed date, the men's clothing ret...
# 0   2021-02-25T00:00:00Z  In 2017, the now-defunct Russian Minecraft ser...
# 0   2021-02-11T00:00:00Z  In June 2020, the site Learnable was allegedly...
# 0   2021-04-15T00:00:00Z  At an unknown date, the Russian anime forum An...
# 0   2021-03-18T00:00:00Z  At an unconfirmed date, the Russian investment...
# 0   2021-04-01T00:00:00Z  At an unconfirmed date, the Italian motherhood...
# 0   2021-04-22T00:00:00Z  At an unknown date, the Romanian book publishe...
# 0   2021-04-08T00:00:00Z  In March 2021, the now-defunct dark web social...
# 0   2021-06-24T00:00:00Z  At an unknown date, the Russian sports news we...
# 0   2021-05-20T00:00:00Z  At an unknown date, the forum for SwordFantasy...
# 0   2021-05-27T00:00:00Z  At an unknown date, the Russian Minecraft serv...
# 0   2021-05-27T00:00:00Z  At an unknown date, the custom game layout bui...
# 0   2021-08-05T00:00:00Z  In June 2021, a user database of over 48 thous...
# 0   2021-07-15T00:00:00Z  In June 2021, data from an unknown Russian tec...
#
#                         site
# 0               bookmate.com
# 0                  500px.com
# 0              sharethis.com
# 0               dubsmash.com
# 0                   8fit.com
# 0                  artsy.net
# 0                 roll20.net
# 0             streeteasy.com
# 0            livejournal.com
# 0                  canva.com
# 0              cafepress.com
# 0                firstvds.ru
# 0                   mnogo.uz
# 0                lencrier.ca
# 0                  zynga.com
# 0              azcentral.com
# 0            lekoolgames.com
# 0                  vkmix.com
# 0              procapital.ru
# 0     thetoywholesaler.co.uk
# 0                aptoide.com
# 0                turistov.ru
# 0             bitrewards.com
# 0                wishbone.io
# 0                 letfan.com
# 0          synergyregions.ru
# 0                wattpad.com
# 0              verified.cash
# 0                    ozon.ru
# 0               kiwitaxi.com
# ..                       ...
# 0                 promofm.ru
# 0                  m.orki.ru
# 0              rabotuvsem.ru
# 0               bizon.com.ua
# 0                    bbtv.az
# 0                megasila.ru
# 0                pda.ntsk.ru
# 0             veloservice.ru
# 0               tamgasoft.kg
# 0             stroykaveka.ru
# 0              chinalots.com
# 0        souzpromarmatura.ru
# 0               bt-system.ru
# 0         exclusiveparfum.ru
# 0      library.lyceum-one.ru
# 0       forums.vkmonline.com
# 0                bonobos.com
# 0             sminecraft.com
# 0              learnable.com
# 0              animeforum.ru
# 0         invest.elevrus.com
# 0            mammeonline.net
# 0             curteaveche.ro
# 0                 atlayo.com
# 0   sport.business-gazeta.ru
# 0           swordfantasy.com
# 0             shadowcraft.ru
# 0    clashofclansbuilder.com
# 0                playkey.net
# 0                    unknown
#
# [71 rows x 3 columns]

# %% [markdown]
# ### Дополнительная часть (необязательная)
# Написать скрипт, который будет получать 50 последних постов указанной группы во Вконтакте.
# Документация к API VK: https://vk.com/dev/methods
# , вам поможет метод [wall.get](https://vk.com/dev/wall.get)
# ```
# GROUP = 'netology'
# TOKEN = УДАЛЯЙТЕ В ВЕРСИИ ДЛЯ ПРОВЕРКИ, НА GITHUB НЕ ВЫКЛАДЫВАТЬ
# ```
#
# В итоге должен формироваться датафрейм со столбцами: `<дата поста> - <текст поста>`

# %%
import json
from bs4 import BeautifulSoup
import requests, time
from datetime import date

source='https://api.vk.com/method/wall.get'
payload = {
    'access_token': '',
    'domain' : 'netology',
    'v':'5.52',
    'count':50
}
def response_info(r, *args, **kwargs):
    print(r.status_code, r.url)

hooks = {'response': response_info} 

session = requests.Session()
res = session.post(source,data=payload,hooks=hooks)
site_json=json.loads(res.text)
# Out:
# 200 https://api.vk.com/method/wall.get

# %%
df = pd.DataFrame()
for item in site_json['response']['items']:
    post_date = date.fromtimestamp(item['date'])
    post_text = item['text']
    row = {'date':post_date,'text':post_text}
    df = pd.concat([df,pd.DataFrame([row])],sort=False)
df
# Out:
#          date                                               text
# 0  2021-08-06  📅 Составляем список дел до конца лета \n \nДо ...
# 0  2021-08-08  *партнёрский пост*\n\nКаждый четвёртый выпускн...
# 0  2021-08-08  Мы очень мало знаем о своём мозге 🤯 \nНескольк...
# 0  2021-08-07  Мы часто делимся историями роста наших студент...
# 0  2021-08-07  Мечтаете попасть в реки? 🤪 \n \nСобрали статьи...
# 0  2021-08-06  Аналитика не такая сложная, если в ней начать ...
# 0  2021-08-05  Доброго времени суток! 😊 \n \nРассказываем, ка...
# 0  2021-08-05  Перемены бывают в жизни каждого из нас: сменит...
# 0  2021-08-05  Берём любимые снеки и идём смотреть новый роли...
# 0  2021-08-04  У нас сегодня Нето-викторина 🤩\n\nМы подготови...
# 0  2021-08-04  💼 16 августа стартует курс «Как стать продакт-...
# 0  2021-08-03  Что делать, если хочется сменить профессию, но...
# 0  2021-08-03  Сильные тексты важны как в маркетинге, так и в...
# 0  2021-08-02  Популярность софт скилов растёт, потому что эт...
# 0  2021-08-02  Лето в самом разгаре и мы надеемся, что вы не ...
# 0  2021-08-02  Залетаем в реки с нашим бесплатным курсом «Про...
# 0  2021-08-01  Рынок образования претерпел серьёзные изменени...
# 0  2021-08-01  Учиться тоже нужно уметь 🤔 \n \nСобрали книги,...
# 0  2021-07-31  У диджитал-профессий есть свои особенности, о ...
# 0  2021-07-30  Компьютеры появились ещё в прошлом столетии, н...
# 0  2021-07-30  В конце каждого месяца заботливо собираем подб...
# 0  2021-07-29  Работа в диджитал ≠ лежать под пальмой где-ниб...
# 0  2021-07-29  Продолжаем снимать новый формат видео, в котор...
# 0  2021-07-28  Ещё несколько дней и начнётся последний месяц ...
# 0  2021-07-28  👩‍🎨 Запустили бесплатный курс «Как стать дизай...
# 0  2021-07-27  Когда действительно любишь работу, часто бывае...
# 0  2021-07-27  Куда развивать стартап — отвечает предпринимат...
# 0  2021-07-26  Написали конспект по открытой лекции «Как учит...
# 0  2021-07-26  Запустили бесплатный курс «Основы интернет-мар...
# 0  2021-07-25  В этом месяце вместе с ProductSense запустили ...
# 0  2021-07-25  Хобби есть? А если найдём? \n \nСобрали подбор...
# 0  2021-07-24  Хабр Карьера помогает классным айти-специалист...
# 0  2021-07-24  Снимать, монтировать и продвигать: собрали под...
# 0  2021-07-23  Иногда обучение на курсах может сильно утомить...
# 0  2021-07-23  По данным исследования «Ромир» 95% россиян пер...
# 0  2021-07-22  Часто люди думают, что другие мыслят так же, к...
# 0  2021-07-22  Доставайте попкорн — вышел новый ролик ЭтоИзи ...
# 0  2021-07-21  Даже если вы не дизайнер или иллюстратор, важн...
# 0  2021-07-21  Дата-сайентисты зарабатывают в среднем в два р...
# 0  2021-07-20  Камера, мотор 🎬 \n\nРассказываем, какими навык...
# 0  2021-07-20  День Нептуна, медляк на дискотеке, страшилки п...
# 0  2021-07-19  Финансисты сегодня стали ключевыми сотрудникам...
# 0  2021-07-19  31 июля в 13:00 пройдёт бесплатный онлайн-мита...
# 0  2021-07-18  Вот так выглядит профессиональная эволюция Ана...
# 0  2021-07-18  Скоро компьютеры будут обладать всеми возможно...
# 0  2021-07-17  В афише — форум о развитии человека, конкурс д...
# 0  2021-07-17  Как разработать контент-стратегию, которая раб...
# 0  2021-07-16  Многие сотрудники крупных компаний так и не ве...
# 0  2021-07-16  Пандемия показала, что продажи в интернете — б...
# 0  2021-07-15  Что делает веб-дизайнер? А UX-дизайнер? \n \nВ...
